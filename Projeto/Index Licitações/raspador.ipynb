# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# URL base
base_url = "https://diariooficialdasprefeituras.org/piaui/buscas?page="

# Número total de páginas
total_pages = 1987

# Inicialize o nome base do arquivo
base_file_name = "licitaçao"

# Estrutura HTML base
base_html = """

    
    
        
    
        <!DOCTYPE html>
<html lang="pt-br">

<head>
    <meta charset="utf-8" />
    <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport" />
    <link href="licitaçao.css" rel="stylesheet" />
    <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/css/bootstrap.min.css"
        integrity="sha384-MCw98/SFnGE8fJT3GXwEOngsV7Zt27NXFoaoApmYm81iuXoPkFOJwJ8ERdknLPMO" rel="stylesheet" />
    <title>Diario Oficial - Licitações</title>
</head>

<body>
    <nav class="navbar navbar-expand-lg navbar navbar-dark bg-dark">
        <a class="navbar-brand" href="index.html">Acesse Diario</a>
        <button aria-controls="navbarNav" aria-expanded="false" aria-label="Alterna navegação" class="navbar-toggler"
            data-target="#navbarNav" data-toggle="collapse" type="button">
            <span class="navbar-toggler-icon"></span>
        </button>
    </nav>

    
    <table class="table mt-4">
        <thead>

        </thead>
        <tbody>
            <!-- Linhas da tabela com dados vão aqui -->
        </tbody>
    </table>

    <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Navegação de Página</title>
    <script src="https://code.jquery.com/jquery-3.6.4.min.js"></script>
</head>
<body>

<nav aria-label="Navegação de página exemplo" class="pagination">
    <ul class="pagination justify-content-center" id="pageList">
        <li class="page-item disabled" id="previousPage">
            <a class="page-link" href="#" tabindex="-1">Anterior</a>
        </li>
    </ul>
</nav>

<script>
    $(document).ready(function() {
        var totalPages = 1987;  // Número total de páginas
        var pagesPerPage = 5;  // Número de páginas exibidas por vez
        var currentPage = parseInt(localStorage.getItem('currentPage')) || 1;   // Página inicial

        function generatePageLinks() {
            $("#pageList").empty();

            // Calcula o ponto médio para manter as páginas centralizadas
            var midPoint = Math.floor(pagesPerPage / 2);
            var startPage = currentPage - midPoint > 0 ? currentPage - midPoint : 1;
            var endPage = startPage + pagesPerPage - 1 <= totalPages ? startPage + pagesPerPage - 1 : totalPages;

            // Adiciona link para a página anterior
            $("#pageList").append('<li class="page-item disabled" id="previousPage"><a class="page-link" href="#" tabindex="-1">Anterior</a></li>');

            // Adiciona links para as páginas
            for (var i = startPage; i <= endPage; i++) {
                var pageLink = '<li class="page-item"><a class="page-link' + (i === currentPage ? ' active' : '') + '" href="licitaçao' + i + '.html">' + i + '</a></li>';
                $("#pageList").append(pageLink);
            }

            // Adiciona link para a próxima página
            $("#pageList").append('<li class="page-item" id="nextPage"><a class="page-link" href="#">Próximo</a></li>');
        }

        // Inicializa a navegação
        generatePageLinks();

        // Destaca a página selecionada
        $("#pageList").on("click", ".page-item:not(:first-child, :last-child) a", function() {
            var selectedPage = parseInt($(this).text());
            if (selectedPage !== currentPage) {
                currentPage = selectedPage;
                localStorage.setItem('currentPage', currentPage);
                generatePageLinks();
                highlightSelectedPage();
            }
        });

        // Função para destacar a página selecionada
        function highlightSelectedPage() {
            $("#pageList .page-item a").removeClass("active");
            $("#pageList .page-item a:contains('" + currentPage + "')").addClass("active");
        }

        // Manipula o clique no link "Próximo"
        $("#pageList").on("click", "#nextPage", function() {
            if (currentPage + pagesPerPage <= totalPages) {
                currentPage += pagesPerPage;
                localStorage.setItem('currentPage', currentPage);
                generatePageLinks();
                highlightSelectedPage();
            }
        });

        // Manipula o clique no link "Anterior"
        $("#pageList").on("click", "#previousPage", function() {
            if (currentPage - pagesPerPage > 0) {
                currentPage -= pagesPerPage;
                localStorage.setItem('currentPage', currentPage);
                generatePageLinks();
                highlightSelectedPage();
            }
        });
    });
</script>











</body>
</html>





    </script>

    <script crossorigin="anonymous" integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo"
        src="https://code.jquery.com/jquery-3.3.1.slim.min.js"></script>
    <script crossorigin="anonymous" integrity="sha384-ZMP7rVo3mIykV+2+9J3UJ46jBk0WLaUAdn689aCwoqbBJiSnjAK/l8WvCWPIPm49"
        src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js"></script>
    <script crossorigin="anonymous" integrity="sha384-ChfqqxuZUCnJSK3+MXmPNIyE6ZbWh2IMqE241rYiqJxyMiZ6OW/JmZQ5stwEULTy"
        src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/js/bootstrap.min.js"></script>
    
</body>

</html>


    


    """

# ...

# Loop através das páginas
for page_number in range(1, total_pages + 1):
    # Construa a URL da página atual
    current_url = f"{base_url}{page_number}"

    # Fazer uma solicitação HTTP para a página
    response = requests.get(current_url)

    # Verificar se a solicitação foi bem-sucedida
    if response.status_code == 200:
        # Parse o conteúdo HTML da página
        soup = BeautifulSoup(response.text, "html.parser")

        # Localize a tabela que você deseja raspar (você precisará inspecionar o código-fonte HTML para isso)
        table = soup.find("table")

        # Verifique se a tabela foi encontrada
        if table:
            # (o restante do seu código para manipular a tabela)

            # Adicione o trecho para substituir a estrutura específica de <a>
            for link in table.find_all("a", class_="fileDoc", href="javascript:void(0)"):
                if link.has_attr("data-file-hash"):
                    # Modifica o atributo "src" do elemento <img>
                    img_tag = link.find("img")
                    if img_tag and img_tag.has_attr("src"):
                        img_tag["src"] = "/Projeto/assets/pdf.png"

                    # Atualiza o atributo "href" do elemento <a>
                    link["href"] = link["href"].replace("javascript:void(0)", "/Projeto/assets/pdf.png")

            # Crie um nome de arquivo exclusivo para cada página
            file_name = f"{base_file_name}{page_number}.html"

            # Crie uma cópia da estrutura HTML base
            current_html = base_html

            # Adicione os dados da tabela à estrutura HTML
            current_html += str(table)

            # Salve o arquivo HTML completo
            with open(file_name, "w", encoding="utf-8") as file:
                file.write(current_html)
        else:
            print(f"Tabela não encontrada na página {current_url}")
    else:
        print(f"Erro ao acessar a página {current_url}. Código de status: {response.status_code}")

# Loop através das URLs
for index, url in enumerate(urls, start=1):
    # Fazer uma solicitação HTTP para a página
    response = requests.get(url)

    # Verificar se a solicitação foi bem-sucedida
    if response.status_code == 200:
        # Parse o conteúdo HTML da página
        soup = BeautifulSoup(response.text, "html.parser")

        # Localize a tabela que você deseja raspar (você precisará inspecionar o código-fonte HTML para isso)
        table = soup.find("table")

        # Verifique se a tabela foi encontrada
        if table:
            # Adicione o prefixo "https://diariooficialdasprefeituras.org/" aos links encontrados na classe "lnkDetail"
            for link in table.find_all("a", class_="lnkDetail"):
                if link.has_attr("href"):
                    link["href"] = urljoin("https://diariooficialdasprefeituras.org/", link["href"])

            # Adicione o prefixo "https://diariooficialdasprefeituras.org/" aos links encontrados na classe "fileLink"
            for link in table.find_all("a", class_="fileLink"):
                if link.has_attr("data-href"):
                    link["data-href"] = urljoin("https://diariooficialdasprefeituras.org/", link["data-href"])

            # Adicione o trecho para substituir a estrutura específica de <a>
            for link in table.find_all("a", class_="fileLink", href="javascript:void(0)"):
                if link.has_attr("data-href"):
                    new_link = soup.new_tag("a", href=link["data-href"], target="_blank")
                    new_link.string = "Baixar"
                    link.replace_with(new_link)

            # Crie um nome de arquivo exclusivo para cada página
            file_name = f"{base_file_name}{index}.html"

            # Crie uma cópia da estrutura HTML base
            current_html = base_html

            # Adicione os dados da tabela à estrutura HTML
            current_html += str(table)

            # Salve o arquivo HTML completo
            with open(file_name, "w", encoding="utf-8") as file:
                file.write(current_html)
        else:
            print(f"Tabela não encontrada na página {url}")
    else:
        print(f"Erro ao acessar a página {url}. Código de status: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Carlos\2023-2-Squad10\Projeto\raspador.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/Carlos/2023-2-Squad10/Projeto/raspador.ipynb#W0sZmlsZQ%3D%3D?line=179'>180</a> current_url = f"{base_url}{page_number}"
#     <a href='vscode-notebook-cell:/c%3A/Users/Carlos/2023-2-Squad10/Projeto/raspador.ipynb#W0sZmlsZQ%3D%3D?line=181'>182</a> # Fazer uma solicitação HTTP para a página
# --> <a href='vscode-notebook-cell:/c%3A/Users/Carlos/2023-2-Squad10/Projeto/raspador.ipynb#W0sZmlsZQ%3D%3D?line=182'>183</a> response = requests.get(current_url)
#     <a href='vscode-notebook-cell:/c%3A/Users/Carlos/2023-2-Squad10/Projeto/raspador.ipynb#W0sZmlsZQ%3D%3D?line=184'>185</a> # Verificar se a solicitação foi bem-sucedida
# ...
