# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Lista de URLs das páginas que você deseja raspar
urls = [
    "https://diariooficialdasprefeituras.org/piaui/buscas?page=1",
    "https://diariooficialdasprefeituras.org/piaui/buscas?page=2",
    "https://diariooficialdasprefeituras.org/piaui/buscas?page=3",
    # Adicione mais URLs, se necessário
]

# Inicialize o nome base do arquivo
base_file_name = "licitaçao"

# Estrutura HTML base
base_html = """

    
    
        
    
        <!DOCTYPE html>
<html lang="pt-br">

<head>
    <meta charset="utf-8" />
    <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport" />
    <link href="licitaçao.css" rel="stylesheet" />
    <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/css/bootstrap.min.css"
        integrity="sha384-MCw98/SFnGE8fJT3GXwEOngsV7Zt27NXFoaoApmYm81iuXoPkFOJwJ8ERdknLPMO" rel="stylesheet" />
    <title>Diario Oficial - Licitações</title>
</head>

<body>
    <nav class="navbar navbar-expand-lg navbar navbar-dark bg-dark">
        <a class="navbar-brand" href="index.html">Acesse Diario</a>
        <button aria-controls="navbarNav" aria-expanded="false" aria-label="Alterna navegação" class="navbar-toggler"
            data-target="#navbarNav" data-toggle="collapse" type="button">
            <span class="navbar-toggler-icon"></span>
        </button>
    </nav>

    <h2>Busca Avançada</h2>

    <div class="card">
        <h2>Filtros</h2>
        <div class="form-group">
            <label for="palavra-chave">Palavra Chave:</label>
            <input type="text" id="palavra-chave" name="palavra-chave">
        </div>
        <div class="form-group">
            <label for="identificador">Identificador:</label>
            <input type="text" id="identificador" name="identificador">
        </div>
        <div class="form-group">
            <label for="numero-edicao">Nº da Edição:</label>
            <select id="numero-edicao" name="numero-edicao">
                <option value="772">Selecione o N° da Edição</option>
                <option value="771">Edição: 530 | Data: 31-07-2023</option>
                <option value="768">Edição: 529 | Data: 28-07-2023</option>
                <option value="767">Edição: 528 | Data: 27-07-2023</option>
                <option value="766">Edição: 527 | Data: 26-07-2023</option>
                <option value="765">Edição: 526 | Data: 25-07-2023</option>
                <option value="764">Edição: 525 | Data: 24-07-2023</option>
                <option value="761">Edição: 524 | Data: 21-07-2023</option>
                <option value="760">Edição: 523 | Data: 20-07-2023</option>
                <option value="759">Edição: 522 | Data: 19-07-2023</option>
                <option value="758">Edição: 521 | Data: 18-07-2023</option>
                <option value="757">Edição: 520 | Data: 17-07-2023</option>
                <option value="754">Edição: 519 | Data: 14-07-2023</option>
                <option value="753">Edição: 518 | Data: 13-07-2023</option>
                <option value="752">Edição: 517 | Data: 12-07-2023</option>
                <option value="751">Edição: 516 | Data: 11-07-2023</option>
                <option value="750">Edição: 515 | Data: 10-07-2023</option>
                <option value="747">Edição: 514 | Data: 07-07-2023</option>
                <option value="746">Edição: 513 | Data: 06-07-2023</option>
                <option value="745">Edição: 512 | Data: 05-07-2023</option>
                <option value="744">Edição: 511 | Data: 04-07-2023</option>
                <option value="743">Edição: 510 | Data: 03-07-2023</option>
                <option value="740">Edição: 509 | Data: 30-06-2023</option>
                <option value="739">Edição: 508 | Data: 29-06-2023</option>
                <option value="738">Edição: 507 | Data: 28-06-2023</option>
                <option value="737">Edição: 506 | Data: 27-06-2023</option>
                <option value="736">Edição: 505 | Data: 26-06-2023</option>
                <option value="733">Edição: 504 | Data: 23-06-2023</option>
                <option value="732">Edição: 503 | Data: 22-06-2023</option>
                <option value="32">Edição: 024 | Data: 22-07-2021</option>
                <option value="31">Edição: 023 | Data: 21-07-2021</option>
                <option value="30">Edição: 022 | Data: 20-07-2021</option>
                <option value="29">Edição: 021 | Data: 19-07-2021</option>
                <option value="26">Edição: 020 | Data: 16-07-2021</option>
                <option value="25">Edição: 019 | Data: 15-07-2021</option>
                <option value="24">Edição: 018 | Data: 14-07-2021</option>
                <option value="23">Edição: 017 | Data: 13-07-2021</option>
                <option value="22">Edição: 016 | Data: 12-07-2021</option>
                <option value="19">Edição: 015 | Data: 09-07-2021</option>
                <option value="18">Edição: 014 | Data: 08-07-2021</option>
                <option value="17">Edição: 013 | Data: 07-07-2021</option>
                <option value="16">Edição: 012 | Data: 06-07-2021</option>
                <option value="15">Edição: 011 | Data: 05-07-2021</option>
                <option value="12">Edição: 010 | Data: 02-07-2021</option>
                <option value="11">Edição: 009 | Data: 01-07-2021</option>
                <option value="10">Edição: 008 | Data: 30-06-2021</option>
                <option value="9">Edição: 007 | Data: 29-06-2021</option>
                <option value="8">Edição: 006 | Data: 28-06-2021</option>
                <option value="5">Edição: 005 | Data: 25-06-2021</option>
                <option value="4">Edição: 004 | Data: 24-06-2021</option>
                <option value="3">Edição: 003 | Data: 23-06-2021</option>
                <option value="2">Edição: 002 | Data: 22-06-2021</option>
                <option value="1">Edição: 001 | Data: 21-06-2021</option>
            </select>
        </div>
        <div class="form-group">
            <label for="classificacao-ato">Classificação do Ato:</label>
            <select id="classificacao-ato" name="classificacao-ato" class="form-control">
                <option value="A">Selecione Classificação do Ato</option>
                <option value="171">A programação financeira</option>
                <option value="202">Alvarás e demais atos administrativos</option>
                <option value="197">Aposentadoria</option>
                <option value="191">Aproveitamento</option>
                <option value="218">Atas</option>
                <option value="201">Atas e deliberações dos conselhos municipais</option>
                <option value="216">Ato Convocatório</option>
                <option value="220">Ato Regimental</option>
                <option value="200">Ato de nomeação da comissão de sindicância</option>
                <option value="180">Ato que criou os cargos ou empregos e sua vacância no quadro de pessoal</option>
                <option value="204">Atos</option>
                <option value="132">Aviso da Adjudicação</option>
                <option value="136">Aviso da Anulação</option>
                <option value="145">Aviso da Cessão de uso</option>
                <option value="143">Aviso da Constituição de comissão de licitação</option>
                <option value="142">Aviso da Convocação para sorteio</option>
                <option value="126">Aviso da Dispensa</option>
                <option value="133">Aviso da Homologação</option>
                <option value="129">Aviso da Impugnação de edital /convite</option>
                <option value="127">Aviso da Inexigibilidade</option>
                <option value="144">Aviso da Notificação de penalidades a licitantes</option>
                <option value="146">Aviso da Permissão de uso</option>
                <option value="140">Aviso da Rescisão de contrato</option>
                <option value="137">Aviso da Revogação</option>
                <option value="113">Aviso da adjudicação</option>
                <option value="117">Aviso da anulação</option>
                <option value="115">Aviso da homologação</option>
                <option value="110">Aviso da impugnação do edital</option>
                <option value="121">Aviso da nomeação do pregoeiro e da sua equipe de apoio</option>
                <option value="118">Aviso da revogação</option>
                <option value="130">Aviso de Julgamento de Habilitação de licitantes</option>
                <option value="213">Aviso de Ratificação</option>
                <option value="124">Aviso de abertura de concorrência, tomada de preço, concurso e leilão</option>
                <option value="223">Aviso de convocação</option>
                <option value="107">Aviso de convocação dos interessados</option>
                <option value="112">Aviso de julgamento e habilitação de licitantes</option>
                <option value="205">Aviso de licitação</option>
                <option value="125">Aviso de modificação de edital de concorrência, tomada de preço, concurso e leilão
                </option>
                <option value="109">Aviso de modificação do edital do pregão</option>
                <option value="141">Aviso do Adiamento de licitação</option>
                <option value="135">Aviso do Contrato</option>
                <option value="131">Aviso do Julgamento e classificação de propostas</option>
                <option value="138">Aviso do Parecer e deliberações da comissão julgadora</option>
                <option value="134">Aviso do Recurso</option>
                <option value="128">Aviso do Registro de preço</option>
                <option value="139">Aviso do Termo Aditivo</option>
                <option value="119">Aviso do cancelamento</option>
                <option value="116">Aviso do extrato de contrato</option>
                <option value="111">Aviso do julgamento e classificação de propostas</option>
                <option value="120">Aviso do parecer e deliberações do pregoeiro</option>
                <option value="114">Aviso do recurso</option>
                <option value="152">Balanço orçamentário</option>
                <option value="168">Circulares</option>
                <option value="155">Compras</option>
                <option value="154">Contratos e seus aditivos</option>
                <option value="214">Convênios</option>
                <option value="175">Créditos adicionais</option>
                <option value="165">Decretos</option>
                <option value="196">Demissão</option>
                <option value="153">Demonstrativo de receitas e despesas</option>
                <option value="169">Despachos</option>
                <option value="219">Edital de Chamada</option>
                <option value="181">Edital de concurso público</option>
                <option value="186">Edital dirigido aos aprovados em concurso público convocando para passe</option>
                <option value="108">Edital do pregão</option>
                <option value="215">Errata</option>
                <option value="151">Execução dos orçamentos</option>
                <option value="195">Exoneração</option>
                <option value="206">Extrato</option>
                <option value="198">Falecimento</option>
                <option value="182">Homologação das inscrições</option>
                <option value="184">Homologação do concurso após julgamento do último recurso</option>
                <option value="177">Lei do estatuto dos servidores municipais e do regime jurídico único</option>
                <option value="178">Lei que estabelece os casos de contratação por tempo determinado para atender a
                    necessidade temporária de excepcional interesse público</option>
                <option value="164">Leis</option>
                <option value="217">Leis Orçamentárias</option>
                <option value="158">Leis de diretrizes orçamentárias</option>
                <option value="187">Nomeação de servidor efetivo, celetista, temporário ou comissionado</option>
                <option value="172">O cronograma de execução orçamentária</option>
                <option value="173">O quadro de cotas trimestrais da despesa</option>
                <option value="157">Orçamentos</option>
                <option value="150">Orçamentos anuais</option>
                <option value="179">Outras disposições legais instituídas pelo município</option>
                <option value="207">Outros</option>
                <option value="203">Outros atos administrativos</option>
                <option value="185">Outros atos de concurso</option>
                <option value="199">Outros atos de pessoal</option>
                <option value="176">Outros atos financeiros</option>
                <option value="170">Outros atos normativos</option>
                <option value="148">Outros tipos de avisos de licitação</option>
                <option value="122">Outros tipos de avisos de licitação</option>
                <option value="160">Parecer prévio</option>
                <option value="156">Planos</option>
                <option value="147">Portaria de nomeação de compradores e comissões de licitações</option>
                <option value="166">Portarias</option>
                <option value="159">Prestação de contas</option>
                <option value="174">Prestação de contas</option>
                <option value="210">Projeto de decreto </option>
                <option value="209">Projeto de indicação</option>
                <option value="212">Projeto de lei</option>
                <option value="188">Promoção</option>
                <option value="193">Readaptação</option>
                <option value="194">Recondução</option>
                <option value="221">Regimento Interno e Suas Atualizações </option>
                <option value="190">Reintegração</option>
                <option value="162">Relatórios de gestão fiscal</option>
                <option value="161">Relatórios resumidos da execução orçamentária</option>
                <option value="123">Relação de todas as compras feitas pela administração direta ou indireta</option>
                <option value="208">Requerimento</option>
                <option value="167">Resoluções</option>
                <option value="183">Resultado dos aprovados e sua classificação</option>
                <option value="192">Reversão</option>
                <option value="222">Termo de Aditamento de Contrato</option>
                <option value="189">Transferência</option>
                <option value="149">Tributos arrecadados</option>
                <option value="163">Versões simplificadas desses documentos</option>
                <option value="211">Veto</option>
            </select>
        </div>

        <div class="form-group">
            <label for="entidade">Entidade:</label>
            <select id="entidade" name="entidade">
                <option value="X">Selecione a Entidade </option>
                <option value="2">Câmara</option>
                <option value="4">Empresa privada</option>
                <option value="1">Prefeitura</option>
            </select>
        </div>
        <div class="form-group">
            <label for="data-inicial">Data Inicial:</label>
            <input type="date" id="data-inicial" name="data-inicial">
        </div>
        <div class="form-group">
            <label for="data-final">Data Final:</label>
            <input type="date" id="data-final" name="data-final">
        </div>
        <button class="btn" type="submit">Filtrar</button>
    </div>

    <table class="table mt-4">
        <thead>

        </thead>
        <tbody>
            <!-- Linhas da tabela com dados vão aqui -->
        </tbody>
    </table>

    <nav aria-label="Navegação de página exemplo" class="pagination">
        <ul class="pagination justify-content-center">
            <li class="page-item disabled">
                <a class="page-link" href="#" tabindex="-1">Anterior</a>
            </li>
            <li class="page-item"><a class="page-link" href="licitaçao1.html">1</a></li>
            <li class="page-item"><a class="page-link" href="licitaçao2.html">2</a></li>
            <li class="page-item"><a class="page-link" href="licitaçao3.html">3</a></li>
            <li class="page-item">
                <a class="page-link" href="#">Próximo</a>
            </li>
        </ul>
    </nav>

 <script>
    document.addEventListener("DOMContentLoaded", function () {
    document.querySelector(".btn").addEventListener("click", function (event) {
        event.preventDefault(); // Impede o envio do formulário e recarregamento da página

        // Obtenha os valores dos campos de filtro
        var palavraChave = document.getElementById("palavra-chave").value.toLowerCase();
        var identificador = document.getElementById("identificador").value.toLowerCase();
        var numeroEdicao = document.getElementById("numero-edicao").value.toLowerCase();
        var classificacaoAto = document.getElementById("classificacao-ato").value.toLowerCase();
        var entidade = document.getElementById("entidade").value.toLowerCase();
        var dataInicial = document.getElementById("data-inicial").value;
        var dataFinal = document.getElementById("data-final").value;

        // Percorra as linhas da tabela
        var linhasTabela = document.getElementById("dadosTabela").getElementsByTagName("tr");
        for (var i = 0; i < linhasTabela.length; i++) {
            var linha = linhasTabela[i];

            // Se a linha for o cabeçalho, pule para a próxima iteração
            if (linha.cells.length === 0) {
                continue;
            }

            var celulas = linha.getElementsByTagName("td");

            // Obtenha os valores das células relevantes
            var valorPalavraChave = celulas[1].textContent.toLowerCase();
            var valorIdentificador = celulas[2].textContent.toLowerCase();
            var valorNumeroEdicao = celulas[0].textContent.toLowerCase();
            var valorClassificacaoAto = celulas[5].textContent.toLowerCase();
            var valorEntidade = celulas[4].textContent.toLowerCase();
            var valorData = celulas[3].textContent;

            // Aplicar lógica de filtro
            var atendeFiltro = (
                (!palavraChave || valorPalavraChave.includes(palavraChave)) &&
                (!identificador || valorIdentificador.includes(identificador)) &&
                (!numeroEdicao || valorNumeroEdicao.includes(numeroEdicao)) &&
                (!classificacaoAto || valorClassificacaoAto.includes(classificacaoAto)) &&
                (!entidade || valorEntidade.includes(entidade)) &&
                (!dataInicial || (valorData >= dataInicial && valorData <= dataFinal))
            );

            // Ocultar ou mostrar a linha com base no filtro
            linha.style.display = atendeFiltro ? "" : "none";
        }
    });
});



    </script>

    <script crossorigin="anonymous" integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo"
        src="https://code.jquery.com/jquery-3.3.1.slim.min.js"></script>
    <script crossorigin="anonymous" integrity="sha384-ZMP7rVo3mIykV+2+9J3UJ46jBk0WLaUAdn689aCwoqbBJiSnjAK/l8WvCWPIPm49"
        src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js"></script>
    <script crossorigin="anonymous" integrity="sha384-ChfqqxuZUCnJSK3+MXmPNIyE6ZbWh2IMqE241rYiqJxyMiZ6OW/JmZQ5stwEULTy"
        src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/js/bootstrap.min.js"></script>
    <script src="filter.js"></script>
</body>

</html>


    


    """

# Loop através das URLs
for index, url in enumerate(urls, start=1):
    # Fazer uma solicitação HTTP para a página
    response = requests.get(url)

    # Verificar se a solicitação foi bem-sucedida
    if response.status_code == 200:
        # Parse o conteúdo HTML da página
        soup = BeautifulSoup(response.text, "html.parser")

        # Localize a tabela que você deseja raspar (você precisará inspecionar o código-fonte HTML para isso)
        table = soup.find("table")

        # Verifique se a tabela foi encontrada
        if table:
            # Substitua "/assets/pdf.png" por "/Projeto/assets/pdf.png" nos links de imagem
            for img in table.find_all("img"):
                if "/assets/pdf.png" in img["src"]:
                    img["src"] = img["src"].replace(
                        "/assets/pdf.png", "/Projeto/assets/pdf.png"
                    )

            # Adicione o prefixo "https://diariooficialdasprefeituras.org/" aos links encontrados na classe "lnkDetail"
            for link in table.find_all("a", class_="lnkDetail"):
                if link.has_attr("href"):
                    link["href"] = urljoin(
                        "https://diariooficialdasprefeituras.org/", link["href"]
                    )

            # Adicione o prefixo "https://diariooficialdasprefeituras.org/" aos links encontrados na classe "fileLink"
            for link in table.find_all("a", class_="fileLink"):
                if link.has_attr("data-href"):
                    link["data-href"] = urljoin(
                        "https://diariooficialdasprefeituras.org/", link["data-href"]
                    )

            # Adicione o trecho para substituir a estrutura específica de <a>
            for link in table.find_all(
                "a", class_="fileLink", href="javascript:void(0)"
            ):
                if link.has_attr("data-href"):
                    new_link = soup.new_tag(
                        "a", href=link["data-href"], target="_blank"
                    )
                    new_link.string = "Baixar"
                    link.replace_with(new_link)

            # Crie um nome de arquivo exclusivo para cada página
            file_name = f"{base_file_name}{index}.html"

            # Crie uma cópia da estrutura HTML base
            current_html = base_html

            # Adicione os dados da tabela à estrutura HTML
            current_html += str(table)

            # Salve o arquivo HTML completo
            with open(file_name, "w", encoding="utf-8") as file:
                file.write(current_html)
        else:
            print(f"Tabela não encontrada na página {url}")
    else:
        print(
            f"Erro ao acessar a página {url}. Código de status: {response.status_code}"
        )

# Salve a estrutura HTML base em um arquivo
with open("licitaçao.html", "w", encoding="utf-8") as file:
    file.write(base_html)
